# %%
# 구글드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')
# drive.mount("/content/drive", force_remount=True)

# %%
# !nvidia-smi                             # GPU 정보 확인
# !head /proc/cpuinfo                     # CPU 정보 확인
# !/usr/local/cuda/bin/nvcc --version     # CUDA 정보 확인
# !pkg-config --modversion opencv

# %%
# !pip install easyocr
# !pip install paho-mqtt
# %cd /content/drive/Shareddrives/EyesOn/final/yolov5

# %%
# !python subBusTarget.py
# Out:
# connect..0
# 1
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>busTimeuuid 확인
# ['ai', 'noticeInfo', 'L', '마포역', '', '', '']
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>busTimeuuid 확인
# ['bigData', 'ok', 'L', '마포역', '', '', '', '', '', '']
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>11300ffffc5511dduuid 확인
# ['android', 'driver', '', 'riding', '']
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>busTimeuuid 확인
# ['ai', 'noticeInfo', 'L', '마포역', '', '', '', '', '', '']
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>busTimeuuid 확인
# ['bigData', 'ok', 'L', '마포역', '', '', '', '', '', '']
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>11300ffffc5511dduuid 확인
# ['android', 'driver', '', 'riding', '']
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>busTimeuuid 확인
# ['ai', 'noticeInfo', 'L', '마포역', '', '', '', '', '', '']
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>busTimeuuid 확인
# ['ai', 'noticeInfo', 'L', '마포역', '', '', '', '', '', '']
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>busTimeuuid 확인
# ['ai', 'noticeInfo', 'L', '마포역', '', '', '', '', '', '']
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>busTimeuuid 확인
# ['bigData', 'ok', 'L', '마포역', '', '', '', '', '', '']
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>11300ffffc5511dduuid 확인
# ['android', 'driver', '', 'riding', '']
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>busTimeuuid 확인
# ['bigData', 'ok', 'L', '마포역', '', '', '', '', '', '']
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>11300ffffc5511dduuid 확인
# ['android', 'driver', '', 'riding', '']
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>busTimeuuid 확인
# ['ai', 'noticeInfo', 'L', '마포역', '', '', '', '', '', '']
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>11300ffffc5511dduuid 확인
# ['android', 'busTime', '', '', '']
